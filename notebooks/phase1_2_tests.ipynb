# %%
import pandas as pd
raw_indicators = pd.read_csv("C:\\Users\\vihaa\\Projects\\cli_recession_model\\data\\raw\\raw_indicators.csv")
raw_indicators.head()
# Out:
#    Unnamed: 0  unemployment_rate  jobless_claims  housing_starts  \
# 0  1980-01-01                6.3             NaN          1341.0
# 1  1980-01-02                NaN             NaN             NaN
# 2  1980-01-03                NaN             NaN             NaN
# 3  1980-01-04                NaN             NaN             NaN
# 4  1980-01-05                NaN        394000.0             NaN
#
#    consumer_sentiment  yield_spread  credit_spread  industrial_production  \
# 0                67.0           NaN            NaN                52.0679
# 1                 NaN         -0.89            NaN                    NaN
# 2                 NaN         -0.85            NaN                    NaN
# 3                 NaN         -0.81            NaN                    NaN
# 4                 NaN           NaN            NaN                    NaN
#
#    recession_indicator       sp500
# 0                  0.0  114.160004
# 1                  NaN         NaN
# ...

# %%
monthly_indicators = pd.read_csv("C:\\Users\\vihaa\\Projects\\cli_recession_model\\data\\processed\\monthly_indicators.csv")
monthly_indicators.tail()
# Out:
#      Unnamed: 0  unemployment_rate  housing_starts  consumer_sentiment  \
# 463  2024-08-01                4.2          1394.0                67.9
# 464  2024-09-01                4.1          1357.0                70.1
# 465  2024-10-01                4.1          1370.0                70.5
# 466  2024-11-01                4.2          1300.0                71.8
# 467  2024-12-01                4.1          1494.0                74.0
#
#      industrial_production  recession_indicator  jobless_claims  yield_spread  \
# 463               100.4309                  0.0        230600.0     -0.094545
# 464                99.8084                  0.0        224500.0      0.101000
# 465                99.4695                  0.0        236250.0      0.123182
# 466                99.2925                  0.0        219200.0      0.098421
# 467               100.3273                  0.0        222750.0      0.165714
#
#      credit_spread        sp500
# 463       1.733636  5648.399902
# ...

# %%
import matplotlib.pyplot as plt
monthly_indicators['credit_spread'].plot()
plt.show()

# %%
cyclical_comp = pd.read_csv("C:\\Users\\vihaa\\Projects\\cli_recession_model\\data\\processed\\cyclical_components.csv")
cyclical_comp.head()
# Out:
#    Unnamed: 0  recession_indicator  unemployment_rate  housing_starts  \
# 0  1986-01-01                  0.0          -0.568025       56.237980
# 1  1986-02-01                  0.0          -0.016750      -49.361406
# 2  1986-03-01                  0.0           0.034881       -2.995941
# 3  1986-04-01                  0.0          -0.012769       72.330078
# 4  1986-05-01                  0.0           0.140646       11.614224
#
#    consumer_sentiment  industrial_production  jobless_claims  yield_spread  \
# 0           -0.540292               1.322787   -21869.235315      0.314323
# 1            0.074113               0.757342   -16300.949523     -0.017313
# 2           -0.411144               0.188071    -1768.995459     -0.207401
# 3            1.004228               0.089772     5650.483243     -0.184939
# 4           -0.079223              -0.009570     8832.448571     -0.164715
#
#    credit_spread      sp500
# 0      -0.469616 -16.261705
# 1      -0.291957  -4.435605
# ...

# %%
cyclical_comp['jobless_claims'].plot()
plt.plot()
# Out:
# []
